# %% [markdown]
# ### This notebook loads the crosscoders by Julian Minder and Clément Dumas and uploads them to Neuronpedia.
# ### This also uploads the activations associated with each feature.

# %%
# %pip install neuronpedia

from dotenv import load_dotenv

# Load NEURONPEDIA_API_KEY from .env file
load_dotenv()


### [less safe] Set Neuronpedia API key manually (get your key from neuronpedia.org/account)
# import os
# os.environ["NEURONPEDIA_API_KEY"] = "YOUR_KEY_HERE"

# %%
from huggingface_hub import hf_hub_download
import pandas as pd

NUM_FEATURES_TO_UPLOAD = 100
LAYER_NUM = 13

print("downloading max activating examples from huggingface")
repo_id = "Butanium/max-activating-examples-gemma-2-2b-l13-mu4.1e-02-lr1e-04"
df_path = hf_hub_download(repo_id=repo_id, filename="feature_df.csv", repo_type="dataset")

df = pd.read_csv(df_path, index_col=0)
available_features = df[(df["tag"].isin(["IT only", "Base only"])) & (df["dead"] == False)]
available_features_idx = available_features.index.tolist()

filtered_features = available_features.head(
    NUM_FEATURES_TO_UPLOAD
)
available_features_idx = filtered_features.index.tolist()
print(len(available_features_idx))
# Out:
# downloading max activating examples from huggingface
# 100

# %%
# get the max act examples db and tokenizer
from tiny_dashboard import OfflineFeatureCentricDashboard
from nnterp import load_model
import gc

gemma_2_it = load_model("google/gemma-2-2b-it", device_map="cuda")
db_path = hf_hub_download(repo_id=repo_id, filename="chat_base_examples_20.db", repo_type="dataset")
gc.collect()
db = OfflineFeatureCentricDashboard.from_db(db_path, gemma_2_it.tokenizer, column_name="entries")

# %%
# get the crosscoders
from neuronpedia.butanium_dictionary_learning.dictionary_learning import CrossCoder

print("getting the crosscoders")
crosscoder = CrossCoder.from_pretrained("Butanium/gemma-2-2b-crosscoder-l13-mu4.1e-02-lr1e-04", from_hub=True)
print("got the crosscoders")
# Out:
# getting the crosscoders
# got the crosscoders

# %%
from neuronpedia.np_vector import NPVector
from neuronpedia.requests.activation_request import Activation

counter = 0
created_np_vectors = []
for feature_idx in available_features_idx:
    counter += 1

    print("Uploading vector for feature", feature_idx)
    print("Progress:", counter, "/", len(available_features_idx))

    # get the weights from the crosscoder and upload it
    crosscoder_weight = crosscoder.encoder.weight[1][:, feature_idx].detach().tolist()

    print("Uploading vector for feature", feature_idx)
    np_vector = NPVector.new(
        label="Crosscoder L13 " + str(feature_idx) + " Dumas/Minder",
        model_id="gemma-2-2b-it",
        layer_num=LAYER_NUM,
        hook_type="hook_resid_pre",
        vector=crosscoder_weight,
        default_steer_strength=20,
    )
    created_np_vectors.append(np_vector)
    # get the associated activations and upload them
    featActs = db.max_activation_examples[feature_idx]
    activationsToUpload: list[Activation] = []
    for act in featActs:
        max_activation_value, tokens, activation_values = act
        activation = Activation(
            tokens=tokens,
            values=activation_values,
        )
        activationsToUpload.append(activation)
    print("Uploading activations for feature", feature_idx)
    np_vector.upload_activations(activationsToUpload)
# Out:
# Uploading vector for feature 55
# Progress: 1 / 100
# Uploading vector for feature 55
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 55
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 60
# Progress: 2 / 100
# Uploading vector for feature 60
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 60
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 78
# Progress: 3 / 100
# Uploading vector for feature 78
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 78
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 82
# Progress: 4 / 100
# Uploading vector for feature 82
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 82
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 95
# Progress: 5 / 100
# Uploading vector for feature 95
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 95
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 112
# Progress: 6 / 100
# Uploading vector for feature 112
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 112
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 119
# Progress: 7 / 100
# Uploading vector for feature 119
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 119
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 130
# Progress: 8 / 100
# Uploading vector for feature 130
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 130
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 140
# Progress: 9 / 100
# Uploading vector for feature 140
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 140
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 221
# Progress: 10 / 100
# Uploading vector for feature 221
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 221
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 222
# Progress: 11 / 100
# Uploading vector for feature 222
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 222
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 231
# Progress: 12 / 100
# Uploading vector for feature 231
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 231
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 239
# Progress: 13 / 100
# Uploading vector for feature 239
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 239
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 263
# Progress: 14 / 100
# Uploading vector for feature 263
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 263
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 267
# Progress: 15 / 100
# Uploading vector for feature 267
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 267
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 286
# Progress: 16 / 100
# Uploading vector for feature 286
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 286
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 291
# Progress: 17 / 100
# Uploading vector for feature 291
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 291
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 312
# Progress: 18 / 100
# Uploading vector for feature 312
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 312
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 335
# Progress: 19 / 100
# Uploading vector for feature 335
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 335
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 377
# Progress: 20 / 100
# Uploading vector for feature 377
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 377
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 378
# Progress: 21 / 100
# Uploading vector for feature 378
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 378
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 383
# Progress: 22 / 100
# Uploading vector for feature 383
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 383
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 388
# Progress: 23 / 100
# Uploading vector for feature 388
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 388
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 418
# Progress: 24 / 100
# Uploading vector for feature 418
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 418
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 465
# Progress: 25 / 100
# Uploading vector for feature 465
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 465
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 478
# Progress: 26 / 100
# Uploading vector for feature 478
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 478
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 500
# Progress: 27 / 100
# Uploading vector for feature 500
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 500
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 548
# Progress: 28 / 100
# Uploading vector for feature 548
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 548
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 550
# Progress: 29 / 100
# Uploading vector for feature 550
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 550
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 551
# Progress: 30 / 100
# Uploading vector for feature 551
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 551
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 561
# Progress: 31 / 100
# Uploading vector for feature 561
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 561
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 591
# Progress: 32 / 100
# Uploading vector for feature 591
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 591
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 593
# Progress: 33 / 100
# Uploading vector for feature 593
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 593
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 603
# Progress: 34 / 100
# Uploading vector for feature 603
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 603
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 610
# Progress: 35 / 100
# Uploading vector for feature 610
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 610
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 621
# Progress: 36 / 100
# Uploading vector for feature 621
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 621
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 640
# Progress: 37 / 100
# Uploading vector for feature 640
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 640
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 652
# Progress: 38 / 100
# Uploading vector for feature 652
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 652
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 653
# Progress: 39 / 100
# Uploading vector for feature 653
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 653
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 692
# Progress: 40 / 100
# Uploading vector for feature 692
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 692
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 707
# Progress: 41 / 100
# Uploading vector for feature 707
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 707
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 711
# Progress: 42 / 100
# Uploading vector for feature 711
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 711
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 735
# Progress: 43 / 100
# Uploading vector for feature 735
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 735
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 743
# Progress: 44 / 100
# Uploading vector for feature 743
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 743
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 746
# Progress: 45 / 100
# Uploading vector for feature 746
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 746
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 751
# Progress: 46 / 100
# Uploading vector for feature 751
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 751
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 771
# Progress: 47 / 100
# Uploading vector for feature 771
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 771
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 785
# Progress: 48 / 100
# Uploading vector for feature 785
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 785
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 792
# Progress: 49 / 100
# Uploading vector for feature 792
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 792
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 793
# Progress: 50 / 100
# Uploading vector for feature 793
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 793
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 816
# Progress: 51 / 100
# Uploading vector for feature 816
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 816
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 834
# Progress: 52 / 100
# Uploading vector for feature 834
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 834
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 878
# Progress: 53 / 100
# Uploading vector for feature 878
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 878
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 883
# Progress: 54 / 100
# Uploading vector for feature 883
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 883
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 901
# Progress: 55 / 100
# Uploading vector for feature 901
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 901
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 923
# Progress: 56 / 100
# Uploading vector for feature 923
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 923
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 939
# Progress: 57 / 100
# Uploading vector for feature 939
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 939
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 946
# Progress: 58 / 100
# Uploading vector for feature 946
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 946
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 981
# Progress: 59 / 100
# Uploading vector for feature 981
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 981
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1019
# Progress: 60 / 100
# Uploading vector for feature 1019
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1019
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1045
# Progress: 61 / 100
# Uploading vector for feature 1045
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1045
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1051
# Progress: 62 / 100
# Uploading vector for feature 1051
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1051
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1056
# Progress: 63 / 100
# Uploading vector for feature 1056
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1056
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1064
# Progress: 64 / 100
# Uploading vector for feature 1064
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1064
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1094
# Progress: 65 / 100
# Uploading vector for feature 1094
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1094
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1105
# Progress: 66 / 100
# Uploading vector for feature 1105
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1105
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1116
# Progress: 67 / 100
# Uploading vector for feature 1116
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1116
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1143
# Progress: 68 / 100
# Uploading vector for feature 1143
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1143
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1157
# Progress: 69 / 100
# Uploading vector for feature 1157
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1157
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1164
# Progress: 70 / 100
# Uploading vector for feature 1164
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1164
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1170
# Progress: 71 / 100
# Uploading vector for feature 1170
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1170
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1187
# Progress: 72 / 100
# Uploading vector for feature 1187
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1187
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1195
# Progress: 73 / 100
# Uploading vector for feature 1195
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1195
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1203
# Progress: 74 / 100
# Uploading vector for feature 1203
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1203
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1248
# Progress: 75 / 100
# Uploading vector for feature 1248
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1248
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1259
# Progress: 76 / 100
# Uploading vector for feature 1259
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1259
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1271
# Progress: 77 / 100
# Uploading vector for feature 1271
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1271
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1277
# Progress: 78 / 100
# Uploading vector for feature 1277
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1277
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1330
# Progress: 79 / 100
# Uploading vector for feature 1330
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1330
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1334
# Progress: 80 / 100
# Uploading vector for feature 1334
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1334
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1353
# Progress: 81 / 100
# Uploading vector for feature 1353
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1353
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1395
# Progress: 82 / 100
# Uploading vector for feature 1395
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1395
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1437
# Progress: 83 / 100
# Uploading vector for feature 1437
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1437
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1462
# Progress: 84 / 100
# Uploading vector for feature 1462
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1462
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1493
# Progress: 85 / 100
# Uploading vector for feature 1493
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1493
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1519
# Progress: 86 / 100
# Uploading vector for feature 1519
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1519
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1523
# Progress: 87 / 100
# Uploading vector for feature 1523
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1523
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1547
# Progress: 88 / 100
# Uploading vector for feature 1547
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1547
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1548
# Progress: 89 / 100
# Uploading vector for feature 1548
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1548
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1570
# Progress: 90 / 100
# Uploading vector for feature 1570
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1570
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1629
# Progress: 91 / 100
# Uploading vector for feature 1629
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1629
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1638
# Progress: 92 / 100
# Uploading vector for feature 1638
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1638
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1649
# Progress: 93 / 100
# Uploading vector for feature 1649
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1649
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1655
# Progress: 94 / 100
# Uploading vector for feature 1655
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1655
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1663
# Progress: 95 / 100
# Uploading vector for feature 1663
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1663
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1665
# Progress: 96 / 100
# Uploading vector for feature 1665
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1665
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1697
# Progress: 97 / 100
# Uploading vector for feature 1697
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1697
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1724
# Progress: 98 / 100
# Uploading vector for feature 1724
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1724
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1742
# Progress: 99 / 100
# Uploading vector for feature 1742
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1742
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.
# Uploading vector for feature 1746
# Progress: 100 / 100
# Uploading vector for feature 1746
# Sending POST request to http://localhost:3000/api/vector/new
# Got a successful response.
# Uploading activations for feature 1746
# Sending POST request to http://localhost:3000/api/activation/upload-batch
# Got a successful response.

# %%
from neuronpedia.np_list import NPList, NPListItem
from neuronpedia.np_vector import NPVector
import webbrowser

# create a new list
new_list = NPList.new("Crosscoder L13 Dumas/Minder - First 100")
print(new_list)
new_list_url = "https://neuronpedia.org/list/" + new_list.id
print(new_list_url)
# Out:
# Sending POST request to http://localhost:3000/api/list/new
# Got a successful response.
# NPList(id='cm40usirc02mtnoyf8m4ddcvc', name='Crosscoder L13 Dumas/Minder - First 100', description='', items=[])
# https://neuronpedia.org/list/cm40usirc02mtnoyf8m4ddcvc

# %%
# turn created np vectors into listitems
list_items = [
    NPListItem(
        model_id=vector.model_id, source=vector.source, index=vector.index, description=vector.label
    )
    for vector in created_np_vectors
]

# batch it up into 100 items at a time for upload
batches = [list_items[i : i + 100] for i in range(0, len(list_items), 100)]

# do the upload
for batch in batches:
    print(batch[0])
    print("Adding batch of", len(batch), "items to the list")
    new_list.add_items(batch)

# print(new_list_url)

webbrowser.open(new_list_url)
# Out:
# NPListItem(model_id='gemma-2-2b-it', source='13-neuronpedia-resid-pre', index='165605925', description='Crosscoder L13 55 Dumas/Minder')
# Adding batch of 100 items to the list
# Sending POST request to http://localhost:3000/api/list/add-features
# Got a successful response.
# True
